# %%
import sys
print(sys.executable)
print(sys.version)

import numpy, pandas, matplotlib
print("OK")
# Out:
# /home/jay/dev/venv/bin/python
# 3.11.14 (main, Oct 10 2025, 08:54:04) [GCC 13.3.0]
# OK
